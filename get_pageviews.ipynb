# %%
# %load_ext autoreload
# %autoreload 2
from get_pageviews import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
d1 = get_month_pageviews_pre_hive()

# %%
d1.head()
# Out:
#            access_method country_iso        n       project   timestamp
# timestamp
# 2013-04-01    mobile web          AF   1000.0  de.wikipedia  2013-04-01
# 2013-04-01       desktop          AF  22000.0  en.wikipedia  2013-04-01
# 2013-04-01    mobile web          AF   8000.0  en.wikipedia  2013-04-01
# 2013-04-01       desktop          AF   8000.0  fa.wikipedia  2013-04-01
# 2013-04-01    mobile web          AF   3000.0  fa.wikipedia  2013-04-01

# %%
d2 = get_month_pageviews_post_hive()

# %%
df = pd.concat([d1, d2], axis=0)

# %%
df.head()
# Out:
#            access_method country_iso month        n       project   timestamp  \
# timestamp
# 2013-04-01    mobile web          AF   NaN   1000.0  de.wikipedia  2013-04-01
# 2013-04-01       desktop          AF   NaN  22000.0  en.wikipedia  2013-04-01
# 2013-04-01    mobile web          AF   NaN   8000.0  en.wikipedia  2013-04-01
# 2013-04-01       desktop          AF   NaN   8000.0  fa.wikipedia  2013-04-01
# 2013-04-01    mobile web          AF   NaN   3000.0  fa.wikipedia  2013-04-01
#
#            year
# timestamp
# 2013-04-01  NaN
# 2013-04-01  NaN
# 2013-04-01  NaN
# 2013-04-01  NaN
# 2013-04-01  NaN

# %%
df = replace_iso_with_country(df)

# %%
df.head()
# Out:
#            access_method country_iso month        n       project   timestamp  \
# timestamp
# 2013-04-01    mobile web          AF   NaN   1000.0  de.wikipedia  2013-04-01
# 2013-04-01       desktop          AF   NaN  22000.0  en.wikipedia  2013-04-01
# 2013-04-01    mobile web          AF   NaN   8000.0  en.wikipedia  2013-04-01
# 2013-04-01       desktop          AF   NaN   8000.0  fa.wikipedia  2013-04-01
# 2013-04-01    mobile web          AF   NaN   3000.0  fa.wikipedia  2013-04-01
#
#            year      country
# timestamp
# 2013-04-01  NaN  Afghanistan
# 2013-04-01  NaN  Afghanistan
# 2013-04-01  NaN  Afghanistan
# 2013-04-01  NaN  Afghanistan
# 2013-04-01  NaN  Afghanistan

# %%
df.to_csv('data/checkpoint.csv')

# %%
df_cube = untidy(df)

# %%
df_cube.head()
# Out:
#              timestamp  ab.wikipedia/desktop/United States  \
# 2013-04-01  2013-04-01                              1000.0
# 2013-05-01  2013-05-01                             63000.0
# 2013-06-01  2013-06-01                             24000.0
# 2013-07-01  2013-07-01                             31000.0
# 2013-08-01  2013-08-01                             81000.0
#
#             ace.wikipedia/desktop/China, People's Republic of  \
# 2013-04-01                                                NaN
# 2013-05-01                                             7000.0
# 2013-06-01                                             6000.0
# 2013-07-01                                             7000.0
# 2013-08-01                                             9000.0
#
#             ace.wikipedia/desktop/Germany  \
# 2013-04-01                            NaN
# 2013-05-01                        11000.0
# 2013-06-01                        21000.0
# 2013-07-01                         9000.0
# 2013-08-01                         9000.0
#
#             ace.wikipedia/desktop/United States  \
# 2013-04-01                               3000.0
# 2013-05-01                              70000.0
# 2013-06-01                              39000.0
# 2013-07-01                              54000.0
# 2013-08-01                             144000.0
#
#             af.wikipedia/desktop/China, People's Republic of  \
# 2013-04-01                                            3000.0
# 2013-05-01                                          108000.0
# 2013-06-01                                           30000.0
# 2013-07-01                                           30000.0
# 2013-08-01                                           42000.0
#
#             af.wikipedia/desktop/France  af.wikipedia/desktop/Germany  \
# 2013-04-01                          NaN                        1000.0
# 2013-05-01                      18000.0                      184000.0
# 2013-06-01                      12000.0                      152000.0
# 2013-07-01                      11000.0                      115000.0
# 2013-08-01                      17000.0                      151000.0
#
#             af.wikipedia/desktop/Netherlands  \
# 2013-04-01                            1000.0
# 2013-05-01                           30000.0
# 2013-06-01                           39000.0
# 2013-07-01                           30000.0
# 2013-08-01                           15000.0
#
#             af.wikipedia/desktop/South Africa  \
# 2013-04-01                            27000.0
# 2013-05-01                           981000.0
# 2013-06-01                           303000.0
# 2013-07-01                           554000.0
# 2013-08-01                          1039000.0
#
#                          ...                 \
# 2013-04-01               ...
# 2013-05-01               ...
# 2013-06-01               ...
# 2013-07-01               ...
# 2013-08-01               ...
#
#             zh.wikipedia/mobile web/Singapore  zh.wikipedia/mobile web/Spain  \
# 2013-04-01                             9000.0                            NaN
# 2013-05-01                           439000.0                        63000.0
# 2013-06-01                           370000.0                        33000.0
# 2013-07-01                           404000.0                        50000.0
# 2013-08-01                           539000.0                        54000.0
#
#             zh.wikipedia/mobile web/Sweden  \
# 2013-04-01                             NaN
# 2013-05-01                         19000.0
# 2013-06-01                         20000.0
# 2013-07-01                         21000.0
# 2013-08-01                         29000.0
#
#             zh.wikipedia/mobile web/Switzerland  \
# 2013-04-01                                  NaN
# 2013-05-01                              16000.0
# 2013-06-01                               8000.0
# 2013-07-01                              16000.0
# 2013-08-01                              15000.0
#
#             zh.wikipedia/mobile web/Thailand  \
# 2013-04-01                            1000.0
# 2013-05-01                           50000.0
# 2013-06-01                           52000.0
# 2013-07-01                           71000.0
# 2013-08-01                           75000.0
#
#             zh.wikipedia/mobile web/United Arab Emirates  \
# 2013-04-01                                           NaN
# 2013-05-01                                        3000.0
# 2013-06-01                                       14000.0
# 2013-07-01                                       10000.0
# 2013-08-01                                       10000.0
#
#             zh.wikipedia/mobile web/United Kingdom  \
# 2013-04-01                                  6000.0
# 2013-05-01                                283000.0
# 2013-06-01                                224000.0
# 2013-07-01                                265000.0
# 2013-08-01                                230000.0
#
#             zh.wikipedia/mobile web/United States  \
# 2013-04-01                                27000.0
# 2013-05-01                              1244000.0
# 2013-06-01                              1271000.0
# 2013-07-01                              1493000.0
# 2013-08-01                              1557000.0
#
#             zh.wikipedia/mobile web/Unknown  zh.wikipedia/mobile web/Vietnam
# 2013-04-01                          31000.0                           2000.0
# 2013-05-01                        1365000.0                          33000.0
# 2013-06-01                        1454000.0                          36000.0
# 2013-07-01                        1597000.0                          50000.0
# 2013-08-01                        1305000.0                          58000.0
#
# [5 rows x 3440 columns]

# %%
df_cube.to_csv('data/cube.csv', index = False)
