# %%
# %load_ext autoreload
# %autoreload 2
from get_pageviews import *

# %%
d1 = get_month_pageviews_pre_hive()

# %%
d1.head()
# Out:
#            access_method country_iso        n       project   timestamp
# timestamp
# 2013-04-01    mobile web          AF   1000.0  de.wikipedia  2013-04-01
# 2013-04-01       desktop          AF  22000.0  en.wikipedia  2013-04-01
# 2013-04-01    mobile web          AF   8000.0  en.wikipedia  2013-04-01
# 2013-04-01       desktop          AF   8000.0  fa.wikipedia  2013-04-01
# 2013-04-01    mobile web          AF   3000.0  fa.wikipedia  2013-04-01

# %%
d2 = get_month_pageviews_post_hive()

# %%
df = pd.concat([d1, d2], axis=0)

# %%
df.head()
# Out:
#            access_method country_iso        n       project   timestamp
# timestamp
# 2013-04-01    mobile web          AF   1000.0  de.wikipedia  2013-04-01
# 2013-04-01       desktop          AF  22000.0  en.wikipedia  2013-04-01
# 2013-04-01    mobile web          AF   8000.0  en.wikipedia  2013-04-01
# 2013-04-01       desktop          AF   8000.0  fa.wikipedia  2013-04-01
# 2013-04-01    mobile web          AF   3000.0  fa.wikipedia  2013-04-01

# %%
df = replace_iso_with_country(df)

# %%
df.tail()
# Out:
#            access_method country_iso     n        project   timestamp  \
# timestamp
# 2017-02-01    mobile web          ZW  11.0   so.wikipedia  2017-02-01
# 2017-02-01    mobile web          ZW  52.0   st.wikipedia  2017-02-01
# 2017-02-01    mobile web          ZW   2.0   te.wikipedia  2017-02-01
# 2017-02-01    mobile web          ZW   1.0  vec.wikipedia  2017-02-01
# 2017-02-01       desktop          ZW   1.0   yo.wikipedia  2017-02-01
#
#              country
# timestamp
# 2017-02-01  Zimbabwe
# 2017-02-01  Zimbabwe
# 2017-02-01  Zimbabwe
# 2017-02-01  Zimbabwe
# 2017-02-01  Zimbabwe

# %%
df.to_csv('data/checkpoint.csv')

# %%
df_cube = untidy(df)

# %%
df_cube.head()
# Out:
#              timestamp  ab.wikipedia/desktop/United States  \
# 2013-04-01  2013-04-01                              1000.0
# 2013-05-01  2013-05-01                             63000.0
# 2013-06-01  2013-06-01                             24000.0
# 2013-07-01  2013-07-01                             31000.0
# 2013-08-01  2013-08-01                             81000.0
#
#             ace.wikipedia/desktop/China, People's Republic of  \
# 2013-04-01                                                NaN
# 2013-05-01                                             7000.0
# 2013-06-01                                             6000.0
# 2013-07-01                                             7000.0
# 2013-08-01                                             9000.0
#
#             ace.wikipedia/desktop/Germany  \
# 2013-04-01                            NaN
# 2013-05-01                        11000.0
# 2013-06-01                        21000.0
# 2013-07-01                         9000.0
# 2013-08-01                         9000.0
#
#             ace.wikipedia/desktop/United States  af.wikipedia/desktop/Canada  \
# 2013-04-01                               3000.0                          NaN
# 2013-05-01                              70000.0                      11000.0
# 2013-06-01                              39000.0                       6000.0
# 2013-07-01                              54000.0                       5000.0
# 2013-08-01                             144000.0                       9000.0
#
#             af.wikipedia/desktop/China, People's Republic of  \
# 2013-04-01                                            3000.0
# 2013-05-01                                          108000.0
# 2013-06-01                                           30000.0
# 2013-07-01                                           30000.0
# 2013-08-01                                           42000.0
#
#             af.wikipedia/desktop/France  af.wikipedia/desktop/Germany  \
# 2013-04-01                          NaN                        1000.0
# 2013-05-01                      18000.0                      184000.0
# 2013-06-01                      12000.0                      152000.0
# 2013-07-01                      11000.0                      115000.0
# 2013-08-01                      17000.0                      151000.0
#
#             af.wikipedia/desktop/Netherlands  \
# 2013-04-01                            1000.0
# 2013-05-01                           30000.0
# 2013-06-01                           39000.0
# 2013-07-01                           30000.0
# 2013-08-01                           15000.0
#
#                            ...                  \
# 2013-04-01                 ...
# 2013-05-01                 ...
# 2013-06-01                 ...
# 2013-07-01                 ...
# 2013-08-01                 ...
#
#             zh.wikipedia/mobile web/Sweden  \
# 2013-04-01                             NaN
# 2013-05-01                         19000.0
# 2013-06-01                         20000.0
# 2013-07-01                         21000.0
# 2013-08-01                         29000.0
#
#             zh.wikipedia/mobile web/Switzerland  \
# 2013-04-01                                  NaN
# 2013-05-01                              16000.0
# 2013-06-01                               8000.0
# 2013-07-01                              16000.0
# 2013-08-01                              15000.0
#
#             zh.wikipedia/mobile web/Thailand  zh.wikipedia/mobile web/Turkey  \
# 2013-04-01                            1000.0                             NaN
# 2013-05-01                           50000.0                         11000.0
# 2013-06-01                           52000.0                         14000.0
# 2013-07-01                           71000.0                          6000.0
# 2013-08-01                           75000.0                          6000.0
#
#             zh.wikipedia/mobile web/United Arab Emirates  \
# 2013-04-01                                           NaN
# 2013-05-01                                        3000.0
# 2013-06-01                                       14000.0
# 2013-07-01                                       10000.0
# 2013-08-01                                       10000.0
#
#             zh.wikipedia/mobile web/United Kingdom  \
# 2013-04-01                                  6000.0
# 2013-05-01                                283000.0
# 2013-06-01                                224000.0
# 2013-07-01                                265000.0
# 2013-08-01                                230000.0
#
#             zh.wikipedia/mobile web/United States  \
# 2013-04-01                                27000.0
# 2013-05-01                              1244000.0
# 2013-06-01                              1271000.0
# 2013-07-01                              1493000.0
# 2013-08-01                              1557000.0
#
#             zh.wikipedia/mobile web/Unknown  zh.wikipedia/mobile web/Vietnam  \
# 2013-04-01                          31000.0                           2000.0
# 2013-05-01                        1365000.0                          33000.0
# 2013-06-01                        1454000.0                          36000.0
# 2013-07-01                        1597000.0                          50000.0
# 2013-08-01                        1305000.0                          58000.0
#
#             zu.wikipedia/desktop/United States
# 2013-04-01                              2000.0
# 2013-05-01                             15000.0
# 2013-06-01                             24000.0
# 2013-07-01                             34000.0
# 2013-08-01                             63000.0
#
# [5 rows x 3796 columns]

# %%
df_cube.to_csv('data/cube.csv', index = False)
